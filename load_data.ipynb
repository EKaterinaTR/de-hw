# %%
#import
import requests
from bs4 import BeautifulSoup
import itertools
from dataclasses import dataclass
import datetime as dt

# %% [markdown]
# ## Скачать основную информацию

# %%
# helpers


# Словарь для преобразования сокращенных названий дней недели
days_translation = {
    'Пн': 'Mon',
    'Вт': 'Tue',
    'Ср': 'Wed',
    'Чт': 'Thu',
    'Пт': 'Fri',
    'Сб': 'Sat',
    'Вс': 'Sun'
}

# Словарь для преобразования сокращенных названий месяцев
months_translation = {
    'Янв': 'Jan',
    'Фев': 'Feb',
    'Мар': 'Mar',
    'Апр': 'Apr',
    'Май': 'May',
    'Июн': 'Jun',
    'Июл': 'Jul',
    'Авг': 'Aug',
    'Сен': 'Sep',
    'Окт': 'Oct',
    'Ноя': 'Nov',
    'Дек': 'Dec'
}

def parse_date(date_str):
    # Разделяем строку на части
    parts = date_str.split()

    # Переводим день недели и месяц
    translated_day = days_translation.get(parts[0])
    translated_month = months_translation.get(parts[1])

    # Проверяем, были ли переведены день и месяц
    if translated_day is None or translated_month is None:
        raise ValueError("Некорректный формат даты или неизвестный день/месяц.")

    # Создаем новую строку с переведенным днем недели и месяцем
    translated_date_str = f"{translated_day} {translated_month} {parts[2]} {parts[3]}"

    # Определяем формат для парсинга
    date_format = '%a %b %d %Y'

    # Преобразуем строку в объект datetime
    return dt.datetime.strptime(translated_date_str, date_format)

# %% [markdown]
# ### собираем ссылки

# %%
def get_ids_from_one_page(page=''):
    """
    page: id страниц - 12(2), 24(3), 36(4) и 
    """
    url = f'https://quest-book.ru/online/list/where/?&s={page}'
    response = requests.get(url)
    #print(url)
    if response.status_code == 200:
        html_content = response.text
        soup = BeautifulSoup(html_content, 'html.parser')
        row = soup.find_all(class_='game-list')[0].find_all('div', class_='row')[0]
        game_ids = []
        game_info_divs = row.find_all('div', class_='game_info')
        for game_info in game_info_divs:
            game_id = game_info.get('data-game-id')
            if game_id:
                game_ids.append(game_id)
        return game_ids
    else:
        print(f"Ошибка: {response.status_code}")
        return []

def get_ids_by_pages():
    ids = []
    current_page_ids = get_ids_from_one_page()
    i = 12
    while current_page_ids != []:
        ids.append(current_page_ids)
        current_page_ids = get_ids_from_one_page(page=f'{i}')
        #print(current_page_ids)
        i += 12
    ids = list(itertools.chain.from_iterable(ids))
    return ids

def get_story_info(id):
    try:
        url = f'https://quest-book.ru/online/view/game{id}'
        response = requests.get(url)
        if response.status_code == 200:
            html_content = response.text
            soup = BeautifulSoup(html_content.encode('ISO-8859-1'), 'html.parser')

            author_info = {}

            author_cell = soup.find('td', text=lambda x: 'Автор' in x)

            # Если ячейка найдена, получить родительский элемент <tr>
            if author_cell:
                author_cell = author_cell.find_next('td')
                author_link = author_cell.find('a')
                author_name = author_link.text.strip()
                author_info['Имя'] = author_name
            print('Имя',author_info['Имя'])
                
            # Извлечение краткого описания
            description_row = soup.find(text="Краткое описание")
            if description_row:
                description_cell = description_row.find_next('td')
                author_info['Краткое описание'] = description_cell.text.strip()
            #print('Краткое описание',author_info.get('Краткое описание'))

            # Извлечение категорий
            categories_row = soup.find(text=lambda x: 'Категории' in x)
            if categories_row:
                categories_cell = categories_row.find_next('td')
                categories = []
                for div in categories_cell.find_all('div'):
                    genre = div.find('b').text.strip()
                    if genre == 'Жанр':
                        gs = div.find_all('a')
                        for g in gs:
                            categories.append(g.text.strip())
                author_info['Категории'] = categories
            #print('Категории',author_info.get('Категории'))


            # Извлечение последнего обновления
            update_row = soup.find(text=lambda x: 'Последнее обновление' in x)
            if update_row:
                update_cell = update_row.find_next('td')
                last_update_str = update_cell.text.strip().split(',')[0] + update_cell.text.strip().split(',')[1]
                last_update = parse_date(last_update_str)
                author_info['Последнее обновление'] = last_update
            #print('Последнее обновление',author_info.get('Последнее обновление'))

            # Извлечение информации о саундтреке
            soundtrack_row = soup.find(text=lambda x: 'Саундтрек' in x)
            if soundtrack_row:
                soundtrack_cell = soundtrack_row.find_next('td')
                author_info['Саундтрек'] = soundtrack_cell.text.strip()
            #print('Саундтрек',author_info.get('Саундтрек'))

            activity_row = soup.find(text=lambda x: 'Активность' in x)
            if activity_row:
                activity_cell = activity_row.find_next('td')
                activity_data = activity_cell.find('div').text.strip().split(': ')
                
                # Извлечение запусков за месяц и всего
                launches_last_month = int(activity_data[1].split('\r')[0])
                total_launches = int(activity_data[2].split('\r')[0])
                
                author_info['Запусков за месяц'] = launches_last_month
                author_info['Всего запусков'] = total_launches
            #print('Запусков за месяц',author_info.get('Запусков за месяц'))

            size_row = soup.find(text=lambda x: 'Размер' in x)
            if size_row:
                size_cell = size_row.find_next('td').text.strip().split(': ')
                #size_data = size_cell.find(text=True).strip().split('</br>')
                size_data = size_cell 
                
                # Извлечение количества параграфов и концовок
                paragraphs_count = int(size_data[1].split('\r')[0])
                endings_count = int(size_data[2].split('\r')[0])
                
                author_info['Количество параграфов'] = paragraphs_count
                author_info['Количество концовок'] = endings_count

            id = id
            name = soup.find('h2', class_='mt-1').text
            author = author_info.get('Имя')
            date_last_version = author_info.get('Последнее обновление')
            short_description = author_info.get('Краткое описание')
            last_month_readed = author_info.get('Запусков за месяц')
            all_readed = author_info.get('Всего запусков')
            likes = soup.find('span', class_='label label-success').find('b').text
            dislikes = soup.find('span', class_='label label-warning').find('b').text
            part_count = author_info.get('Количество параграфов') 
            end_count = author_info.get('Количество концовок')
            music = author_info.get('Саундтрек')
            genres = author_info.get('Категории')
            return Story(id=id,
                        name=name, 
                        author=author,
                        date_last_version=date_last_version,
                        short_description=short_description,
                        last_month_readed=last_month_readed,
                        all_readed=all_readed,
                        likes=likes,
                        dislikes=dislikes,
                        part_count=part_count,
                        end_count=end_count,
                        music=music,
                        genres=genres)
        else:
            print(f"Ошибка: {response.status_code}")
            return None
    except Exception as e:
        print(e)
        return None

@dataclass    
class Story:
    id:int
    name:str
    author:str
    date_last_version: dt.datetime
    short_description:str 
    last_month_readed:int
    all_readed:int
    likes:int
    dislikes:int
    part_count:int
    end_count:int
    music:str
    genres: list[str]

# %%
story_ids =  get_ids_by_pages()
print(len(story_ids))
# Out:
# 641

# %%
len(story_ids)
# Out:
# 641

# %%
stories=[]
for id in story_ids:
    print(id)
    story =get_story_info(id)
    print(story)
    stories.append(story)
    #print(story['name'])
# Out:
# 17423
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1388852564.py:45: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   author_cell = soup.find('td', text=lambda x: 'Автор' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1388852564.py:56: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   description_row = soup.find(text="Краткое описание")
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1388852564.py:63: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   categories_row = soup.find(text=lambda x: 'Категории' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1388852564.py:78: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   update_row = soup.find(text=lambda x: 'Последнее обновление' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1388852564.py:87: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soundtrack_row = soup.find(text=lambda x: 'Саундтрек' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1388852564.py:93: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   activity_row = soup.find(text=lambda x: 'Активность' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1388852564.py:106: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   size_row = soup.find(text=lambda x: 'Размер' in x)
# Имя Da_Tenshi
# Запусков за месяц 42
# ['Параграфов', '62\r\n\t\t\t\t\t\t\t\t\tКонцовок', '14']
# Story(id='17423', name='Визит в дом 16', author='Da_Tenshi', date_last_version=datetime.datetime(2025, 1, 18, 0, 0), short_description='детектив, криминал, конец 19 века', last_month_readed=42, all_readed=42, likes='1', dislikes='1', part_count=62, end_count=14, music='Нет', genres=['детектив'])
# 17415
# Имя Smurfik 228
# Запусков за месяц 22
# ['Параграфов', '26\r\n\t\t\t\t\t\t\t\t\tКонцовок', '10']
# Story(id='17415', name='Память', author='Smurfik 228', date_last_version=datetime.datetime(2025, 1, 15, 0, 0), short_description='вы всё забыли и должны по кусочкам восстанавливать себе память', last_month_readed=22, all_readed=22, likes='0', dislikes='3', part_count=26, end_count=10, music='Нет', genres=['поиск', 'повседневность'])
# 17403
# Имя Pete Pr
# Запусков за месяц 141
# ['Параграфов', '32\r\n\t\t\t\t\t\t\t\t\tКонцовок', '5']
# Story(id='17403', name='Спасение нерядовой ели', author='Pete Pr', date_last_version=datetime.datetime(2025, 1, 15, 0, 0), short_description='Специально для конкурса "Новый Год 2025".', last_month_readed=141, all_readed=141, likes='9', dislikes='0', part_count=32, end_count=5, music='Нет', genres=['повседневность'])
# 17391
# Имя Златолюб
# Запусков за месяц 100
# ['Параграфов', '51\r\n\t\t\t\t\t\t\t\t\tКонцовок', '10']
# Story(id='17391', name='Ты - Робин Гуд!', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 30, 0, 0), short_description='Будни Шервудского леса и окрестностей', last_month_readed=100, all_readed=100, likes='3', dislikes='0', part_count=51, end_count=10, music='Нет', genres=['история', 'приключения'])
# 17390
# Имя Скальд
# Запусков за месяц 73
# ['Параграфов', '12\r\n\t\t\t\t\t\t\t\t\tКонцовок', '3']
# Story(id='17390', name='Зимний рейс', author='Скальд', date_last_version=datetime.datetime(2025, 1, 1, 0, 0), short_description='Новогодняя история в сеттинге "Анэксадо"!', last_month_readed=73, all_readed=73, likes='8', dislikes='0', part_count=12, end_count=3, music='Нет', genres=['приключения', 'фантастика'])
# 17372
# Имя Златолюб
# Запусков за месяц 192
# ['Параграфов', '70\r\n\t\t\t\t\t\t\t\t\tКонцовок', '32']
# Story(id='17372', name='Разбойники Шервудского леса', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 19, 0, 0), short_description='Юный американский школьник оказывается в Шервудском лесу времён Робина Гуда', last_month_readed=192, all_readed=192, likes='3', dislikes='0', part_count=70, end_count=32, music='Нет', genres=['история', 'фэнтези', 'приключения'])
# 17302
# Имя Скальд
# Запусков за месяц 134
# ['Параграфов', '1003\r\n\t\t\t\t\t\t\t\t\tКонцовок', '2']
# Story(id='17302', name='Тандем', author='Скальд', date_last_version=datetime.datetime(2024, 12, 27, 0, 0), short_description='История анэксадо в мире посткиберпанка!', last_month_readed=134, all_readed=134, likes='9', dislikes='2', part_count=1003, end_count=2, music='Нет', genres=['детектив', 'романтика'])
# 15847
# Имя SibSpar
# Запусков за месяц 526
# ['Параграфов', '274\r\n\t\t\t\t\t\t\t\t\tКонцовок', '18']
# Story(id='15847', name='Узурпатор', author='SibSpar', date_last_version=datetime.datetime(2025, 1, 3, 0, 0), short_description='История мести и дворцовых интриг', last_month_readed=526, all_readed=526, likes='сторигейм месяца', dislikes='0', part_count=274, end_count=18, music='Нет', genres=['боевик', 'фэнтези'])
# 17367
# Имя Златолюб
# Запусков за месяц 100
# ['Параграфов', '65\r\n\t\t\t\t\t\t\t\t\tКонцовок', '29']
# Story(id='17367', name='За короля и сокровища', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 11, 0, 0), short_description='Юный бродячий жонглёр ищет сокровища в мире Подземелий и Драконов', last_month_readed=100, all_readed=188, likes='5', dislikes='0', part_count=65, end_count=29, music='Нет', genres=['фэнтези', 'ролевая игра'])
# 17363
# Имя Златолюб
# Запусков за месяц 119
# ['Параграфов', '23\r\n\t\t\t\t\t\t\t\t\tКонцовок', '8']
# Story(id='17363', name='Пропавший Волшебник', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 11, 0, 0), short_description='Юный ученик волшебника ищет приключения в мире Подземелий и Драконов', last_month_readed=119, all_readed=207, likes='5', dislikes='0', part_count=23, end_count=8, music='Нет', genres=['фэнтези', 'ролевая игра'])
# 15782
# 'Имя'
# None
# 17289
# Имя Дмитрий Дударь
# Запусков за месяц 82
# ['Параграфов', '500\r\n\t\t\t\t\t\t\t\t\tКонцовок', '16']
# Story(id='17289', name='Вой Оборотня', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 11, 10, 0, 0), short_description='Книга-игра Джонатана Грина из серии Fighting Fantasy.  Найдите лекарство от ликантропии и победите Князя Оборотней!', last_month_readed=82, all_readed=349, likes='12', dislikes='0', part_count=500, end_count=16, music='Нет', genres=['приключения', 'фэнтези'])
# 17255
# Имя Арсений Воробьев
# Запусков за месяц 7
# ['Параграфов', '29\r\n\t\t\t\t\t\t\t\t\tКонцовок', '12']
# Story(id='17255', name='губка боб', author='Арсений Воробьев', date_last_version=datetime.datetime(2024, 11, 9, 0, 0), short_description='губка боб', last_month_readed=7, all_readed=88, likes='2', dislikes='2', part_count=29, end_count=12, music='Нет', genres=['квест'])
# 17109
# Имя Скальд
# Запусков за месяц 49
# ['Параграфов', '877\r\n\t\t\t\t\t\t\t\t\tКонцовок', '5']
# Story(id='17109', name='Homo insipiens', author='Скальд', date_last_version=datetime.datetime(2024, 11, 12, 0, 0), short_description='История анэксадо в мире стимпанка!', last_month_readed=49, all_readed=359, likes='18', dislikes='2', part_count=877, end_count=5, music='Нет', genres=['приключения', 'фантастика'])
# 17278
# Имя Aleks Otter
# Запусков за месяц 19
# ['Параграфов', '12\r\n\t\t\t\t\t\t\t\t\tКонцовок', '0']
# Story(id='17278', name='Пленник', author='Aleks Otter', date_last_version=datetime.datetime(2024, 11, 2, 0, 0), short_description='Я просыпаюсь в пустой комнате, и не могу понять, как попал сюда...', last_month_readed=19, all_readed=81, likes='5', dislikes='0', part_count=12, end_count=0, music='Нет', genres=['юмор', 'ужасы'])
# 17176
# Имя cahizoku
# Запусков за месяц 15
# ['Параграфов', '19\r\n\t\t\t\t\t\t\t\t\tКонцовок', '1']
# Story(id='17176', name='Жажда', author='cahizoku', date_last_version=datetime.datetime(2024, 11, 4, 0, 0), short_description='У вас только одна цель', last_month_readed=15, all_readed=74, likes='4', dislikes='1', part_count=19, end_count=1, music='Нет', genres=['история'])
# 17232
# Имя Дмитрий Дударь
# Запусков за месяц 49
# ['Параграфов', '350\r\n\t\t\t\t\t\t\t\t\tКонцовок', '15']
# Story(id='17232', name='Сказание о Загоре', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 10, 26, 0, 0), short_description='Собери отряд из 4 героев и исследуй замок, чтобы найти и победить могучего колдуна Загора.', last_month_readed=49, all_readed=247, likes='9', dislikes='0', part_count=350, end_count=15, music='Нет', genres=['приключения', 'ролевая игра'])
# 15702
# Имя Виктор Луд
# Запусков за месяц 51
# ['Параграфов', '266\r\n\t\t\t\t\t\t\t\t\tКонцовок', '2']
# Story(id='15702', name='Оксана против зомби', author='Виктор Луд', date_last_version=datetime.datetime(2024, 10, 20, 0, 0), short_description='Ночь. Монстры заполонили город. Каким-то чудом я всё ещё жива...', last_month_readed=51, all_readed=488, likes='21', dislikes='0', part_count=266, end_count=2, music='Нет', genres=['боевик', 'ужасы', 'квест'])
# 17205
# Имя Белоусов Михаил Николаеви
# Запусков за месяц 29
# ['Параграфов', '16\r\n\t\t\t\t\t\t\t\t\tКонцовок', '6']
# Story(id='17205', name='Путешествие в Афины', author='Белоусов Михаил Николаеви', date_last_version=datetime.datetime(2024, 10, 6, 0, 0), short_description='Вы - молодой фальшивомонетчик, вынужденный бежать из родного города.', last_month_readed=29, all_readed=121, likes='3', dislikes='1', part_count=16, end_count=6, music='Нет', genres=['история'])
# 17168
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[89], line 4
#       2 for id in story_ids:
#       3     print(id)
# ----> 4     story =get_story_info(id)
#       5     print(story)
#       6     stories.append(story)
#
# Cell In[88], line 38, in get_story_info(id)
#      36 try:
#      37     url = f'https://quest-book.ru/online/view/game{id}'
# ---> 38     response = requests.get(url)
#      39     if response.status_code == 200:
#      40         html_content = response.text
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     717     raise OSError("cannot read from timed out object")
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#     721     self._timeout_occurred = True
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1300     if flags != 0:
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#    1306     return super().recv_into(buffer, nbytes, flags)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python313\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1136 try:
#    1137     if buffer is not None:
# -> 1138         return self._sslobj.read(len, buffer)
#    1139     else:
#    1140         return self._sslobj.read(len)
#
# KeyboardInterrupt:
