# %%
#import
import requests
from bs4 import BeautifulSoup
import itertools
from dataclasses import dataclass
import datetime as dt
import psycopg

# %% [markdown]
# ## Скачать основную информацию

# %%
# helpers


# Словарь для преобразования сокращенных названий дней недели
days_translation = {
    'Пн': 'Mon',
    'Вт': 'Tue',
    'Ср': 'Wed',
    'Чт': 'Thu',
    'Пт': 'Fri',
    'Сб': 'Sat',
    'Вс': 'Sun'
}

# Словарь для преобразования сокращенных названий месяцев
months_translation = {
    'Янв': 'Jan',
    'Фев': 'Feb',
    'Мар': 'Mar',
    'Апр': 'Apr',
    'Май': 'May',
    'Июн': 'Jun',
    'Июл': 'Jul',
    'Авг': 'Aug',
    'Сен': 'Sep',
    'Окт': 'Oct',
    'Ноя': 'Nov',
    'Дек': 'Dec'
}

def parse_date(date_str):
    # Разделяем строку на части
    parts = date_str.split()

    # Переводим день недели и месяц
    translated_day = days_translation.get(parts[0])
    translated_month = months_translation.get(parts[1])

    # Проверяем, были ли переведены день и месяц
    if translated_day is None or translated_month is None:
        raise ValueError("Некорректный формат даты или неизвестный день/месяц.")

    # Создаем новую строку с переведенным днем недели и месяцем
    translated_date_str = f"{translated_day} {translated_month} {parts[2]} {parts[3]}"

    # Определяем формат для парсинга
    date_format = '%a %b %d %Y'

    # Преобразуем строку в объект datetime
    return dt.datetime.strptime(translated_date_str, date_format)

# %% [markdown]
# ### собираем ссылки

# %%
def get_ids_from_one_page(page=''):
    """
    page: id страниц - 12(2), 24(3), 36(4) и 
    """
    url = f'https://quest-book.ru/online/list/where/?&s={page}'
    response = requests.get(url)
    #print(url)
    if response.status_code == 200:
        html_content = response.text
        soup = BeautifulSoup(html_content, 'html.parser')
        row = soup.find_all(class_='game-list')[0].find_all('div', class_='row')[0]
        game_ids = []
        game_info_divs = row.find_all('div', class_='game_info')
        for game_info in game_info_divs:
            game_id = game_info.get('data-game-id')
            if game_id:
                game_ids.append(game_id)
        return game_ids
    else:
        print(f"Ошибка: {response.status_code}")
        return []

def get_ids_by_pages():
    ids = []
    current_page_ids = get_ids_from_one_page()
    i = 12
    while current_page_ids != []:
        ids.append(current_page_ids)
        current_page_ids = get_ids_from_one_page(page=f'{i}')
        #print(current_page_ids)
        i += 12
    ids = list(itertools.chain.from_iterable(ids))
    return ids

def get_story_info(id):
    try:
        url = f'https://quest-book.ru/online/view/game{id}'
        response = requests.get(url)
        if response.status_code == 200:
            html_content = response.text
            soup = BeautifulSoup(html_content.encode('ISO-8859-1'), 'html.parser')

            author_info = {}

            author_cell = soup.find('td', text=lambda x: 'Автор' in x)

            # Если ячейка найдена, получить родительский элемент <tr>
            if author_cell:
                author_cell = author_cell.find_next('td')
                author_link = author_cell.find('a')
                author_name = author_link.text.strip()
                author_info['Имя'] = author_name
            #print('Имя',author_info['Имя'])
                
            # Извлечение краткого описания
            description_row = soup.find(text="Краткое описание")
            if description_row:
                description_cell = description_row.find_next('td')
                author_info['Краткое описание'] = description_cell.text.strip()
            #print('Краткое описание',author_info.get('Краткое описание'))

            # Извлечение категорий
            categories_row = soup.find(text=lambda x: 'Категории' in x)
            if categories_row:
                categories_cell = categories_row.find_next('td')
                categories = []
                for div in categories_cell.find_all('div'):
                    genre = div.find('b').text.strip()
                    if genre == 'Жанр':
                        gs = div.find_all('a')
                        for g in gs:
                            categories.append(g.text.strip())
                author_info['Категории'] = categories
            #print('Категории',author_info.get('Категории'))


            # Извлечение последнего обновления
            update_row = soup.find(text=lambda x: 'Последнее обновление' in x)
            if update_row:
                update_cell = update_row.find_next('td')
                last_update_str = update_cell.text.strip().split(',')[0] + update_cell.text.strip().split(',')[1]
                last_update = parse_date(last_update_str)
                author_info['Последнее обновление'] = last_update
            #print('Последнее обновление',author_info.get('Последнее обновление'))

            # Извлечение информации о саундтреке
            soundtrack_row = soup.find(text=lambda x: 'Саундтрек' in x)
            if soundtrack_row:
                soundtrack_cell = soundtrack_row.find_next('td')
                author_info['Саундтрек'] = soundtrack_cell.text.strip()
            #print('Саундтрек',author_info.get('Саундтрек'))

            activity_row = soup.find(text=lambda x: 'Активность' in x)
            if activity_row:
                activity_cell = activity_row.find_next('td')
                activity_data = activity_cell.find('div').text.strip().split(': ')
                
                # Извлечение запусков за месяц и всего
                launches_last_month = int(activity_data[1].split('\r')[0])
                total_launches = int(activity_data[2].split('\r')[0])
                
                author_info['Запусков за месяц'] = launches_last_month
                author_info['Всего запусков'] = total_launches
            #print('Запусков за месяц',author_info.get('Запусков за месяц'))

            size_row = soup.find(text=lambda x: 'Размер' in x)
            if size_row:
                size_cell = size_row.find_next('td').text.strip().split(': ')
                #size_data = size_cell.find(text=True).strip().split('</br>')
                size_data = size_cell 
                
                # Извлечение количества параграфов и концовок
                paragraphs_count = int(size_data[1].split('\r')[0])
                endings_count = int(size_data[2].split('\r')[0])
                
                author_info['Количество параграфов'] = paragraphs_count
                author_info['Количество концовок'] = endings_count

            id = id
            name = soup.find('h2', class_='mt-1').text
            author = author_info.get('Имя')
            date_last_version = author_info.get('Последнее обновление')
            short_description = author_info.get('Краткое описание')
            last_month_readed = author_info.get('Запусков за месяц')
            all_readed = author_info.get('Всего запусков')
            likes = soup.find('span', class_='label label-success').find('b').text
            dislikes = soup.find('span', class_='label label-warning').find('b').text
            part_count = author_info.get('Количество параграфов') 
            end_count = author_info.get('Количество концовок')
            music = author_info.get('Саундтрек')
            genres = author_info.get('Категории')
            return Story(id=id,
                        name=name, 
                        author=author,
                        date_last_version=date_last_version,
                        short_description=short_description,
                        last_month_readed=last_month_readed,
                        all_readed=all_readed,
                        likes=likes,
                        dislikes=dislikes,
                        part_count=part_count,
                        end_count=end_count,
                        music=music,
                        genres=genres)
        else:
            print(f"Ошибка: {response.status_code}")
            return None
    except Exception as e:
        print(e)
        return None

@dataclass    
class Story:
    id:int
    name:str
    author:str
    date_last_version: dt.datetime
    short_description:str 
    last_month_readed:int
    all_readed:int
    likes:int
    dislikes:int
    part_count:int
    end_count:int
    music:str
    genres: list[str]

# %% [markdown]
# ## Cохранение в бд функция

# %%
def insert_story_and_genres(story: Story,cursor):
    try:
        # Вставка жанров (если они не существуют)
        for genre in story.genres:
            cursor.execute("""
                INSERT INTO genres (name) VALUES (%s)
                ON CONFLICT (name) DO NOTHING;
            """, (genre,))

        # Вставка произведения
        cursor.execute("""
            INSERT INTO stories (id, name, author, date_last_version, short_description,
                                 last_month_readed, all_readed, likes, dislikes,
                                 part_count, end_count, music)
            VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s);
        """, (story.id, story.name, story.author, story.date_last_version,
              story.short_description, story.last_month_readed,
              story.all_readed, story.likes, story.dislikes,
              story.part_count, story.end_count, story.music))

        # Получение ID жанров и связывание их с произведением
        for genre in story.genres:
            cursor.execute("SELECT id FROM genres WHERE name = %s;", (genre,))
            genre_id = cursor.fetchone()[0]
            cursor.execute("""
                INSERT INTO story_genres (story_id, genre_id)
                VALUES (%s, %s);
            """, (story.id, genre_id))

        # Подтверждение транзакции
        connection.commit()

    except Exception as e:
        print(f"An error occurred: {e}")

# %% [markdown]
# ## Использования функций

# %%
story_ids =  get_ids_by_pages()
print(len(story_ids))
# Out:
# 641

# %%
len(story_ids)
# Out:
# 641

# %%
stories=[]
for id in story_ids:
    print(id)
    story =get_story_info(id)
    print(story)
    stories.append(story)
    #print(story['name'])
# Out:
# 17423
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1625426128.py:45: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   author_cell = soup.find('td', text=lambda x: 'Автор' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1625426128.py:56: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   description_row = soup.find(text="Краткое описание")
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1625426128.py:63: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   categories_row = soup.find(text=lambda x: 'Категории' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1625426128.py:78: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   update_row = soup.find(text=lambda x: 'Последнее обновление' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1625426128.py:87: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   soundtrack_row = soup.find(text=lambda x: 'Саундтрек' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1625426128.py:93: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   activity_row = soup.find(text=lambda x: 'Активность' in x)
# C:\Users\User\AppData\Local\Temp\ipykernel_11760\1625426128.py:106: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   size_row = soup.find(text=lambda x: 'Размер' in x)
# Имя Da_Tenshi
# Story(id='17423', name='Визит в дом 16', author='Da_Tenshi', date_last_version=datetime.datetime(2025, 1, 18, 0, 0), short_description='детектив, криминал, конец 19 века', last_month_readed=45, all_readed=45, likes='1', dislikes='1', part_count=62, end_count=14, music='Нет', genres=['детектив'])
# 17415
# Имя Smurfik 228
# Story(id='17415', name='Память', author='Smurfik 228', date_last_version=datetime.datetime(2025, 1, 15, 0, 0), short_description='вы всё забыли и должны по кусочкам восстанавливать себе память', last_month_readed=25, all_readed=25, likes='1', dislikes='3', part_count=26, end_count=10, music='Нет', genres=['поиск', 'повседневность'])
# 17403
# Имя Pete Pr
# Story(id='17403', name='Спасение нерядовой ели', author='Pete Pr', date_last_version=datetime.datetime(2025, 1, 15, 0, 0), short_description='Специально для конкурса "Новый Год 2025".', last_month_readed=141, all_readed=141, likes='9', dislikes='0', part_count=32, end_count=5, music='Нет', genres=['повседневность'])
# 17391
# Имя Златолюб
# Story(id='17391', name='Ты - Робин Гуд!', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 30, 0, 0), short_description='Будни Шервудского леса и окрестностей', last_month_readed=101, all_readed=101, likes='3', dislikes='0', part_count=51, end_count=10, music='Нет', genres=['история', 'приключения'])
# 17390
# Имя Скальд
# Story(id='17390', name='Зимний рейс', author='Скальд', date_last_version=datetime.datetime(2025, 1, 1, 0, 0), short_description='Новогодняя история в сеттинге "Анэксадо"!', last_month_readed=75, all_readed=75, likes='8', dislikes='0', part_count=12, end_count=3, music='Нет', genres=['приключения', 'фантастика'])
# 17372
# Имя Златолюб
# Story(id='17372', name='Разбойники Шервудского леса', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 19, 0, 0), short_description='Юный американский школьник оказывается в Шервудском лесу времён Робина Гуда', last_month_readed=192, all_readed=192, likes='3', dislikes='0', part_count=70, end_count=32, music='Нет', genres=['история', 'фэнтези', 'приключения'])
# 17302
# Имя Скальд
# Story(id='17302', name='Тандем', author='Скальд', date_last_version=datetime.datetime(2024, 12, 27, 0, 0), short_description='История анэксадо в мире посткиберпанка!', last_month_readed=138, all_readed=138, likes='9', dislikes='2', part_count=1003, end_count=2, music='Нет', genres=['детектив', 'романтика'])
# 15847
# Имя SibSpar
# Story(id='15847', name='Узурпатор', author='SibSpar', date_last_version=datetime.datetime(2025, 1, 3, 0, 0), short_description='История мести и дворцовых интриг', last_month_readed=535, all_readed=535, likes='сторигейм месяца', dislikes='0', part_count=274, end_count=18, music='Нет', genres=['боевик', 'фэнтези'])
# 17367
# Имя Златолюб
# Story(id='17367', name='За короля и сокровища', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 11, 0, 0), short_description='Юный бродячий жонглёр ищет сокровища в мире Подземелий и Драконов', last_month_readed=100, all_readed=189, likes='5', dislikes='0', part_count=65, end_count=29, music='Нет', genres=['фэнтези', 'ролевая игра'])
# 17363
# Имя Златолюб
# Story(id='17363', name='Пропавший Волшебник', author='Златолюб', date_last_version=datetime.datetime(2024, 12, 11, 0, 0), short_description='Юный ученик волшебника ищет приключения в мире Подземелий и Драконов', last_month_readed=116, all_readed=207, likes='5', dislikes='0', part_count=23, end_count=8, music='Нет', genres=['фэнтези', 'ролевая игра'])
# 15782
# 'Имя'
# None
# 17289
# Имя Дмитрий Дударь
# Story(id='17289', name='Вой Оборотня', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 11, 10, 0, 0), short_description='Книга-игра Джонатана Грина из серии Fighting Fantasy.  Найдите лекарство от ликантропии и победите Князя Оборотней!', last_month_readed=79, all_readed=349, likes='12', dislikes='0', part_count=500, end_count=16, music='Нет', genres=['приключения', 'фэнтези'])
# 17255
# Имя Арсений Воробьев
# Story(id='17255', name='губка боб', author='Арсений Воробьев', date_last_version=datetime.datetime(2024, 11, 9, 0, 0), short_description='губка боб', last_month_readed=7, all_readed=88, likes='2', dislikes='2', part_count=29, end_count=12, music='Нет', genres=['квест'])
# 17109
# Имя Скальд
# Story(id='17109', name='Homo insipiens', author='Скальд', date_last_version=datetime.datetime(2024, 11, 12, 0, 0), short_description='История анэксадо в мире стимпанка!', last_month_readed=49, all_readed=359, likes='18', dislikes='2', part_count=877, end_count=5, music='Нет', genres=['приключения', 'фантастика'])
# 17278
# Имя Aleks Otter
# Story(id='17278', name='Пленник', author='Aleks Otter', date_last_version=datetime.datetime(2024, 11, 2, 0, 0), short_description='Я просыпаюсь в пустой комнате, и не могу понять, как попал сюда...', last_month_readed=20, all_readed=82, likes='5', dislikes='0', part_count=12, end_count=0, music='Нет', genres=['юмор', 'ужасы'])
# 17176
# Имя cahizoku
# Story(id='17176', name='Жажда', author='cahizoku', date_last_version=datetime.datetime(2024, 11, 4, 0, 0), short_description='У вас только одна цель', last_month_readed=16, all_readed=75, likes='4', dislikes='1', part_count=19, end_count=1, music='Нет', genres=['история'])
# 17232
# Имя Дмитрий Дударь
# Story(id='17232', name='Сказание о Загоре', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 10, 26, 0, 0), short_description='Собери отряд из 4 героев и исследуй замок, чтобы найти и победить могучего колдуна Загора.', last_month_readed=49, all_readed=247, likes='9', dislikes='0', part_count=350, end_count=15, music='Нет', genres=['приключения', 'ролевая игра'])
# 15702
# Имя Виктор Луд
# Story(id='15702', name='Оксана против зомби', author='Виктор Луд', date_last_version=datetime.datetime(2024, 10, 20, 0, 0), short_description='Ночь. Монстры заполонили город. Каким-то чудом я всё ещё жива...', last_month_readed=51, all_readed=489, likes='21', dislikes='0', part_count=266, end_count=2, music='Нет', genres=['боевик', 'ужасы', 'квест'])
# 17205
# Имя Белоусов Михаил Николаеви
# Story(id='17205', name='Путешествие в Афины', author='Белоусов Михаил Николаеви', date_last_version=datetime.datetime(2024, 10, 6, 0, 0), short_description='Вы - молодой фальшивомонетчик, вынужденный бежать из родного города.', last_month_readed=29, all_readed=121, likes='3', dislikes='1', part_count=16, end_count=6, music='Нет', genres=['история'])
# 17168
# Имя Дмитрий Дударь
# Story(id='17168', name='Глаз Дракона', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 9, 26, 0, 0), short_description='Книга-игра Яна Ливингстона.  Помогите главному герою найти легендарную статую Золотого Дракона в опасном подземелье .', last_month_readed=62, all_readed=902, likes='24', dislikes='0', part_count=360, end_count=18, music='Нет', genres=['приключения', 'фэнтези'])
# 17124
# Имя StarStalk147
# Story(id='17124', name='Важное поручение', author='StarStalk147', date_last_version=datetime.datetime(2024, 9, 23, 0, 0), short_description='Вам поручено забрать важные документы', last_month_readed=30, all_readed=318, likes='11', dislikes='0', part_count=133, end_count=3, music='Нет', genres=['приключения', 'квест', 'фантастика'])
# 17164
# Имя Ксения Устинова
# Story(id='17164', name='Приключения в волшебном лесу', author='Ксения Устинова', date_last_version=datetime.datetime(2024, 9, 20, 0, 0), short_description='К двум подругам приходит, волшебная кошка Голди. Волшебному лесу нужна помощь! Да начнутся новые приключения.', last_month_readed=12, all_readed=67, likes='1', dislikes='2', part_count=15, end_count=1, music='Нет', genres=['сказка', 'приключения'])
# 17030
# Имя Андрей Рулин
# Story(id='17030', name='Огни Сантьяго', author='Андрей Рулин', date_last_version=datetime.datetime(2024, 9, 17, 0, 0), short_description='Помогите эмигранту построить карьеру в чилийской столице.', last_month_readed=13, all_readed=235, likes='6', dislikes='1', part_count=29, end_count=2, music='Нет', genres=['приключения', 'повседневность', 'стратегия', 'симулятор'])
# 17098
# Имя aloneinthedarknesss
# Story(id='17098', name='Неудачники: Космическое такси', author='aloneinthedarknesss', date_last_version=datetime.datetime(2024, 11, 22, 0, 0), short_description='Анэксадо Хантер Моралес переживает не лучшие времена, однако один заказ может изменить всё.', last_month_readed=26, all_readed=412, likes='15', dislikes='0', part_count=45, end_count=5, music='Нет', genres=['фантастика'])
# 10505
# 'Имя'
# None
# 17100
# Имя ДарьяLfhmz
# Story(id='17100', name='Лидер', author='ДарьяLfhmz', date_last_version=datetime.datetime(2024, 8, 13, 0, 0), short_description='Игра, которая поможет каждому руководителю оценить, насколько он прокачал эмоциональный интеллект', last_month_readed=2, all_readed=87, likes='3', dislikes='2', part_count=42, end_count=1, music='Нет', genres=['повседневность'])
# 17052
# Имя Дмитрий Дударь
# Story(id='17052', name='Золотой Дракон: Склеп Вампира', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 7, 1, 0, 0), short_description='Книга-игра Дэйва Морриса. Хватит ли вам смелости, чтобы победить ужасного лорда вампиров? Сражайтесь, исследуйте, разгадывайте тайны!!', last_month_readed=25, all_readed=702, likes='21', dislikes='1', part_count=260, end_count=20, music='Нет', genres=['приключения', 'фэнтези'])
# 15931
# Имя Андрей Рулин
# Story(id='15931', name='Аргентинское чудо', author='Андрей Рулин', date_last_version=datetime.datetime(2024, 6, 14, 0, 0), short_description='Хотите создать препарат, который бы продлил молодость солдатам? Тогда вперёд, Аргенина-мать зовёт!', last_month_readed=13, all_readed=677, likes='8', dislikes='4', part_count=38, end_count=3, music='Нет', genres=['фантастика', 'стратегия'])
# 16133
# Имя света нет
# Story(id='16133', name='А может блог?', author='света нет', date_last_version=datetime.datetime(2024, 5, 29, 0, 0), short_description='Получится ли у вас стать блогером?', last_month_readed=0, all_readed=149, likes='3', dislikes='1', part_count=25, end_count=2, music='Нет', genres=['симулятор', 'повседневность'])
# 16152
# Имя junk911
# Story(id='16152', name='Семь кругов бюрократического ада', author='junk911', date_last_version=datetime.datetime(2024, 5, 27, 0, 0), short_description='Вы - обычный клерк в огромной государственной корпорации. Однажды вы обнаруживаете серьезные нарушения и коррупцию в высших эшелонах власти.', last_month_readed=2, all_readed=172, likes='4', dislikes='2', part_count=21, end_count=8, music='Нет', genres=['квест'])
# 16136
# Имя Таня Ефимова
# Story(id='16136', name='Русалка Анфиса', author='Таня Ефимова', date_last_version=datetime.datetime(2024, 5, 23, 0, 0), short_description='Рискованное приключение', last_month_readed=6, all_readed=140, likes='1', dislikes='4', part_count=25, end_count=2, music='Нет', genres=['приключения', 'фантастика'])
# 16128
# Имя Любина Ева Евгеньевна
# Story(id='16128', name='Игроман Лосяш', author='Любина Ева Евгеньевна', date_last_version=datetime.datetime(2024, 5, 21, 0, 0), short_description='Крош и Ёжик уговорили Лосяша дать им поиграть в новую игру на своём компьютере. После их ухода Лосяш попробовал сам в неё поиграть, но слишк', last_month_readed=8, all_readed=202, likes='4', dislikes='1', part_count=21, end_count=2, music='Нет', genres=['сказка'])
# 16058
# Имя Ксения Лившиц
# Story(id='16058', name='Судьба интеллигента.', author='Ксения Лившиц', date_last_version=datetime.datetime(2024, 5, 23, 0, 0), short_description='Пройди сквозь пламя Великой Французской революции. Выжить или умереть - зависит от тебя. Или нет..?', last_month_readed=15, all_readed=278, likes='8', dislikes='0', part_count=119, end_count=36, music='Да', genres=['выживание', 'стратегия', 'ролевая игра'])
# 16097
# Имя Исмаил
# Story(id='16097', name='Сокровища прошлого', author='Исмаил', date_last_version=datetime.datetime(2024, 5, 16, 0, 0), short_description='Молодой археолог Алексей отправляется на поиски древнего артефакта, скрытого в таинственном лесу. На его пути встречаются заброшенная хижина', last_month_readed=6, all_readed=192, likes='2', dislikes='4', part_count=24, end_count=10, music='Нет', genres=['выживание', 'поиск', 'головоломка', 'ужасы'])
# 15779
# Имя Дмитрий Дударь
# Story(id='15779', name='Корпорация СТРАХ', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 4, 21, 0, 0), short_description='Станьте супергероем , победите могущественных злодеев и найдите улики, позволяющие раскрыть место секретной встречи корпорации СТРАХ!', last_month_readed=5, all_readed=559, likes='12', dislikes='0', part_count=350, end_count=10, music='Нет', genres=['приключения', 'ролевая игра', 'фантастика'])
# 15766
# Имя Творческая Роза
# Story(id='15766', name='Мир моими глазами', author='Творческая Роза', date_last_version=datetime.datetime(2024, 4, 7, 0, 0), short_description='Это история о путешественнике, который отправляется в неизвестные страны с компанией “Surprise Travel”.', last_month_readed=2, all_readed=81, likes='1', dislikes='3', part_count=34, end_count=5, music='Нет', genres=['приключения', 'повседневность'])
# 15761
# Имя Дмитрий Дударь
# Story(id='15761', name='Одинокий Волк - Огонь на воде', author='Дмитрий Дударь', date_last_version=datetime.datetime(2024, 4, 17, 0, 0), short_description='Книга-игра про Одинокого Волка, в которой вас ждут незабываемые приключения, опасные путешествия, сражения с врагами и смертельные ловушки.', last_month_readed=33, all_readed=838, likes='19', dislikes='1', part_count=250, end_count=30, music='Нет', genres=['приключения', 'фэнтези'])
# 15756
# Имя Александр Мельников
# Story(id='15756', name='Приключения Гауста', author='Александр Мельников', date_last_version=datetime.datetime(2024, 3, 29, 0, 0), short_description='Захватывающее приключения бесстрашного мышонка.', last_month_readed=16, all_readed=174, likes='2', dislikes='1', part_count=21, end_count=10, music='Нет', genres=['сказка', 'приключения'])
# 15724
# Имя Энкин Флед
# Story(id='15724', name='Чудная обыденность', author='Энкин Флед', date_last_version=datetime.datetime(2024, 3, 24, 0, 0), short_description='Небольшой отрывок из повседневной жизни колдуна-отшельника', last_month_readed=27, all_readed=714, likes='18', dislikes='4', part_count=27, end_count=8, music='Нет', genres=['повседневность', 'фэнтези', 'юмор'])
# 15736
# Имя Анна Ремезова
# Story(id='15736', name='Тени в уме', author='Анна Ремезова', date_last_version=datetime.datetime(2024, 3, 24, 0, 0), short_description='Лукас Натан Гейзер верит в абсолютно все теории заговора, городские легенды и интернет-крипипасты. А всё потому, что он шизофреник.', last_month_readed=5, all_readed=180, likes='3', dislikes='6', part_count=18, end_count=3, music='Нет', genres=['история', 'повседневность'])
# 15733
# 'Имя'
# None
# 15692
# 'Имя'
# None
# 14313
# Имя Виктор Луд
# Story(id='14313', name='Однажды в Нью-Провиденсе: Тайна тольтекского идола', author='Виктор Луд', date_last_version=datetime.datetime(2024, 5, 3, 0, 0), short_description='Раскрой зловещую тайну и останься в живых!', last_month_readed=101, all_readed=1499, likes='28', dislikes='1', part_count=174, end_count=9, music='Нет', genres=['детектив', 'триллер', 'мистика'])
# 15677
# Имя Наталия Шубникова
# Story(id='15677', name='Лиса и волк', author='Наталия Шубникова', date_last_version=datetime.datetime(2024, 3, 3, 0, 0), short_description='Квестбук по сказке "Лиса и волк"', last_month_readed=2, all_readed=131, likes='0', dislikes='0', part_count=11, end_count=0, music='Нет', genres=['сказка'])
# 15663
# Имя SibSpar
# Story(id='15663', name='Железо и лёд', author='SibSpar', date_last_version=datetime.datetime(2025, 1, 3, 0, 0), short_description='Капитану древнего ордена предстоит дать отпор армии хаоса', last_month_readed=22, all_readed=532, likes='28', dislikes='0', part_count=80, end_count=5, music='Нет', genres=['фантастика', 'боевик'])
# 13736
# 'Имя'
# None
# 14540
# Имя Gard
# Story(id='14540', name='Генезис: Посвящение', author='Gard', date_last_version=datetime.datetime(2024, 2, 25, 0, 0), short_description='Рекруту элитного ордена предстоит осуществить миссию для защиты планеты на которую вторглись инопланетяне.', last_month_readed=52, all_readed=1345, likes='28', dislikes='1', part_count=1432, end_count=19, music='Нет', genres=['приключения', 'боевик', 'фантастика'])
# 14569
# Имя Творческая Роза
# Story(id='14569', name='Забытая в Исландии', author='Творческая Роза', date_last_version=datetime.datetime(2024, 2, 1, 0, 0), short_description='Захватывающая история о приключениях молодой девушки', last_month_readed=13, all_readed=235, likes='8', dislikes='4', part_count=201, end_count=7, music='Нет', genres=['история', 'легенды', 'приключения'])
# 15213
# Имя Анна Бутковская
# Story(id='15213', name='Меч и корона', author='Анна Бутковская', date_last_version=datetime.datetime(2024, 1, 21, 0, 0), short_description='О том, как ты свою принцессу спасал(-а)!', last_month_readed=6, all_readed=327, likes='14', dislikes='1', part_count=84, end_count=4, music='Нет', genres=['сказка', 'фэнтези', 'юмор'])
# 15597
# Имя Софья Артемьева
# Story(id='15597', name='Сказочные каникулы', author='Софья Артемьева', date_last_version=datetime.datetime(2024, 1, 8, 0, 0), short_description='Проведи свои каникулы в компании сказочных героев!', last_month_readed=2, all_readed=206, likes='1', dislikes='1', part_count=11, end_count=6, music='Нет', genres=['сказка'])
# 15274
# Имя Дмитрий Дударь
# Story(id='15274', name='Кощеева Цепь', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 12, 19, 0, 0), short_description='Удивительная книга-игра, в которой можно сразиться со Змеем-Горынычем, а, возможно, и победить самого Кощея!  Выбор за тобой, богатырь!', last_month_readed=20, all_readed=803, likes='12', dislikes='1', part_count=240, end_count=17, music='Нет', genres=['сказка', 'фэнтези'])
# 14668
# Имя DDD
# Story(id='14668', name='Арена', author='DDD', date_last_version=datetime.datetime(2024, 1, 14, 0, 0), short_description='Борись, выживай, побеждай', last_month_readed=7, all_readed=461, likes='9', dislikes='3', part_count=40, end_count=7, music='Нет', genres=['приключения', 'боевик', 'фэнтези', 'квест'])
# 15210
# Имя Ilfat Fahriev
# Story(id='15210', name='Некромант. История Зла', author='Ilfat Fahriev', date_last_version=datetime.datetime(2023, 12, 9, 0, 0), short_description='Захвати Королевство, воскрешай мертвецов и стань Повелителем армии Зла!', last_month_readed=11, all_readed=494, likes='7', dislikes='5', part_count=26, end_count=2, music='Нет', genres=['сказка', 'фэнтези', 'приключения'])
# 14637
# Имя elChеm
# Story(id='14637', name='Цветы предательства', author='elChеm', date_last_version=datetime.datetime(2024, 3, 1, 0, 0), short_description='Приключения Корела в волшебном мире Таламонта продолжаются!', last_month_readed=10, all_readed=562, likes='14', dislikes='1', part_count=86, end_count=4, music='Нет', genres=['фэнтези', 'квест', 'приключения'])
# 14835
# Имя Little genocidnik
# Story(id='14835', name='Увидимся, любимая', author='Little genocidnik', date_last_version=datetime.datetime(2023, 12, 4, 0, 0), short_description='Дальнейшие отношения зависят только от нее', last_month_readed=23, all_readed=268, likes='3', dislikes='0', part_count=16, end_count=3, music='Нет', genres=['романтика'])
# 14651
# Имя tawny.owl
# Story(id='14651', name='Истории Хранителей. Белая гробница.', author='tawny.owl', date_last_version=datetime.datetime(2023, 11, 28, 0, 0), short_description='7 Хранителей. 8 Гробниц. История спасения одного мира.', last_month_readed=1, all_readed=192, likes='5', dislikes='0', part_count=34, end_count=3, music='Нет', genres=['фэнтези'])
# 8302
# 'Имя'
# None
# 14838
# Имя Евгения Мушковец
# Story(id='14838', name='Репка. Старая сказка на новый лад.', author='Евгения Мушковец', date_last_version=datetime.datetime(2023, 11, 14, 0, 0), short_description='Игра по мотивам русской народной сказки "Репка".', last_month_readed=30, all_readed=249, likes='8', dislikes='0', part_count=13, end_count=1, music='Нет', genres=['сказка'])
# 14667
# Имя Анна Бутковская
# Story(id='14667', name='Наследство Дженнингс-холла', author='Анна Бутковская', date_last_version=datetime.datetime(2023, 11, 10, 0, 0), short_description='Расследование убийства в Дженнингс-холле', last_month_readed=45, all_readed=924, likes='15', dislikes='0', part_count=13, end_count=4, music='Нет', genres=['история', 'детектив'])
# 14584
# 'Имя'
# None
# 14531
# Имя tawny.owl
# Story(id='14531', name='Истории Хранителей. Красная гробница.', author='tawny.owl', date_last_version=datetime.datetime(2023, 11, 15, 0, 0), short_description='7 Хранителей. 8 Гробниц. История спасения одного мира.', last_month_readed=0, all_readed=337, likes='6', dislikes='1', part_count=153, end_count=10, music='Да', genres=['фэнтези'])
# 14635
# Имя tes vi
# Story(id='14635', name='Святослав идет "на Вы"', author='tes vi', date_last_version=datetime.datetime(2023, 10, 16, 0, 0), short_description='Святослав Игоревич', last_month_readed=5, all_readed=123, likes='0', dislikes='5', part_count=17, end_count=2, music='Нет', genres=['история'])
# 14449
# Имя ZestenLight
# Story(id='14449', name='Сопротивление Империи', author='ZestenLight', date_last_version=datetime.datetime(2023, 9, 30, 0, 0), short_description='Вы - член сопротивления, бросившего вызов Империи, захватившей всю планету.', last_month_readed=6, all_readed=164, likes='2', dislikes='3', part_count=55, end_count=2, music='Да', genres=['приключения'])
# 14587
# Имя Pollly
# Story(id='14587', name='Путешествие в запределье', author='Pollly', date_last_version=datetime.datetime(2023, 9, 29, 0, 0), short_description='Ты очнулся в странном и новом для себя мире. Отправься в путешествие по 4 разным королевствам.', last_month_readed=2, all_readed=244, likes='7', dislikes='0', part_count=55, end_count=1, music='Да', genres=['квест', 'фэнтези'])
# 14564
# Имя СтепанОншин
# Story(id='14564', name='Симулятор Президента (демократии Южной Америки)', author='СтепанОншин', date_last_version=datetime.datetime(2024, 9, 15, 0, 0), short_description='Возглавьте страну и ее переход к "демократии"', last_month_readed=60, all_readed=1452, likes='14', dislikes='2', part_count=35, end_count=1, music='Нет', genres=['история', 'стратегия', 'симулятор'])
# 14406
# Имя DDD
# Story(id='14406', name='Escape: Тайная комната', author='DDD', date_last_version=datetime.datetime(2023, 10, 17, 0, 0), short_description='Выберись из комнаты, объединяя различные предметы', last_month_readed=4, all_readed=670, likes='26', dislikes='0', part_count=14, end_count=1, music='Нет', genres=['приключения'])
# 14462
# Имя cahizoku
# Story(id='14462', name='Дневник страника', author='cahizoku', date_last_version=datetime.datetime(2023, 9, 5, 0, 0), short_description='история о приключениях одного странника, в не обладающего магией, в мире который живёт ею', last_month_readed=6, all_readed=113, likes='4', dislikes='2', part_count=45, end_count=4, music='Нет', genres=['приключения'])
# 14514
# Имя BookPen
# Story(id='14514', name='Дальний Край: Жаркие Земли', author='BookPen', date_last_version=datetime.datetime(2023, 9, 1, 0, 0), short_description='Путешествие по диким землям Жаркой Земли.', last_month_readed=0, all_readed=236, likes='6', dislikes='3', part_count=59, end_count=8, music='Нет', genres=['приключения'])
# 14526
# Имя tawny.owl
# Story(id='14526', name='Истории Хранителей. Зелёная гробница.', author='tawny.owl', date_last_version=datetime.datetime(2023, 10, 26, 0, 0), short_description='7 Хранителей. 8 Гробниц. История спасения одного мира.', last_month_readed=0, all_readed=500, likes='8', dislikes='1', part_count=53, end_count=4, music='Нет', genres=['приключения'])
# 14240
# Имя Маг07
# Story(id='14240', name='Тайна космической станции', author='Маг07', date_last_version=datetime.datetime(2024, 7, 6, 0, 0), short_description='Это интересная история в ходе которой ты оказываешься на старой космической станции.', last_month_readed=19, all_readed=408, likes='9', dislikes='0', part_count=80, end_count=10, music='Да', genres=['поиск'])
# 13327
# Имя Савелий Еляков
# Story(id='13327', name='Сталкер Зов Монолита', author='Савелий Еляков', date_last_version=datetime.datetime(2024, 7, 24, 0, 0), short_description='Я монолит иди ко мне', last_month_readed=10, all_readed=289, likes='4', dislikes='4', part_count=196, end_count=36, music='Нет', genres=['выживание'])
# 14482
# Имя Картонка
# Story(id='14482', name='The Inside. Акт-1', author='Картонка', date_last_version=datetime.datetime(2023, 8, 19, 0, 0), short_description='Вперёд, в абсурдный мир Ан!', last_month_readed=5, all_readed=416, likes='9', dislikes='1', part_count=90, end_count=6, music='Нет', genres=['сказка'])
# 14447
# Имя ZestenLight
# Story(id='14447', name='Война за Остров', author='ZestenLight', date_last_version=datetime.datetime(2023, 8, 14, 0, 0), short_description='Казуальная стратегия на тему войны островов', last_month_readed=22, all_readed=510, likes='7', dislikes='5', part_count=18, end_count=2, music='Нет', genres=['стратегия'])
# 14390
# Имя Лу
# Story(id='14390', name='Лес', author='Лу', date_last_version=datetime.datetime(2023, 9, 1, 0, 0), short_description='Сможешь ли ты пройти сквозь лес кошмаров?', last_month_readed=7, all_readed=659, likes='15', dislikes='2', part_count=183, end_count=14, music='Нет', genres=['история'])
# 14439
# Имя elChеm
# Story(id='14439', name='Семена раздора', author='elChеm', date_last_version=datetime.datetime(2024, 2, 1, 0, 0), short_description='Изгой Корел оказался участником дерзкой авантюры, которой суждено нарушить хрупкое равновесие на границе трёх государств.', last_month_readed=10, all_readed=959, likes='34', dislikes='1', part_count=102, end_count=3, music='Нет', genres=['фэнтези'])
# 14301
# 'Имя'
# None
# 14436
# Имя ZestenLight
# Story(id='14436', name='Gacha: Последние дни', author='ZestenLight', date_last_version=datetime.datetime(2023, 7, 28, 0, 0), short_description='Пройдите историю о последних днях мира, получая себе случайных персонажей.', last_month_readed=1, all_readed=187, likes='8', dislikes='2', part_count=33, end_count=1, music='Да', genres=['приключения'])
# 14422
# 'Имя'
# None
# 13288
# 'Имя'
# None
# 9971
# 'Имя'
# None
# 4335
# Имя DDD
# Story(id='4335', name='Квестаун II', author='DDD', date_last_version=datetime.datetime(2023, 7, 31, 0, 0), short_description='Знакомство с Гаспаром', last_month_readed=1, all_readed=164, likes='7', dislikes='1', part_count=68, end_count=1, music='Нет', genres=['приключения'])
# 14380
# Имя Emily Gross
# Story(id='14380', name='Выбор верховной ведьмы', author='Emily Gross', date_last_version=datetime.datetime(2023, 6, 25, 0, 0), short_description='О ловкости, хитрости и колдовстве', last_month_readed=2, all_readed=235, likes='3', dislikes='6', part_count=22, end_count=6, music='Нет', genres=['выживание'])
# 14353
# Имя Дмитрий Дударь
# Story(id='14353', name='Ян Ливингстон "Армии Смерти"', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 6, 18, 0, 0), short_description='Собери  большую армию и победи войска Теневого Демона! Тебя ждут могучие враги, непростые загадки и смертоносные ловушки!', last_month_readed=10, all_readed=311, likes='10', dislikes='1', part_count=400, end_count=10, music='Нет', genres=['приключения'])
# 14169
# 'Имя'
# None
# 14343
# Имя Максим Бривка
# Story(id='14343', name='Посмертие', author='Максим Бривка', date_last_version=datetime.datetime(2023, 6, 13, 0, 0), short_description='Посмертные приключения грешной души в поисках искупления и прощения.', last_month_readed=3, all_readed=653, likes='14', dislikes='1', part_count=72, end_count=15, music='Нет', genres=['приключения', 'мистика'])
# 6100
# Имя Вадим Медяновский
# Story(id='6100', name='Симулятор жизни', author='Вадим Медяновский', date_last_version=datetime.datetime(2023, 6, 9, 0, 0), short_description='Симулятор жизни играть', last_month_readed=5, all_readed=246, likes='6', dislikes='3', part_count=73, end_count=2, music='Нет', genres=['выживание'])
# 14326
# Имя Дмитрий Дударь
# Story(id='14326', name='Кровавый меч: Боевые ямы Крарта', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 6, 11, 0, 0), short_description='Удастся ли тебе найти Эмблему Победы? На твоем пути встанут свирепые монстры и опасные ловушки. Боевые ямы Крарта ждут тебя!', last_month_readed=9, all_readed=284, likes='8', dislikes='0', part_count=240, end_count=10, music='Нет', genres=['приключения'])
# 14229
# Имя Mathematicus
# Story(id='14229', name='Замысел Творца', author='Mathematicus', date_last_version=datetime.datetime(2023, 6, 10, 0, 0), short_description='Мадрид, 1568 год. Здесь сегодня решится твоя судьба.', last_month_readed=4, all_readed=828, likes='17', dislikes='2', part_count=88, end_count=6, music='Нет', genres=['история'])
# 14330
# Имя Максим Бривка
# Story(id='14330', name='Странный остров', author='Максим Бривка', date_last_version=datetime.datetime(2023, 6, 10, 0, 0), short_description='Небольшое приключение на загадочном островке...', last_month_readed=0, all_readed=156, likes='6', dislikes='0', part_count=13, end_count=3, music='Нет', genres=['приключения'])
# 10621
# Имя Иван Красса
# Story(id='10621', name='Чапаев', author='Иван Красса', date_last_version=datetime.datetime(2023, 6, 7, 0, 0), short_description='Герои народных анекдотов в интерактивном приключении', last_month_readed=2, all_readed=179, likes='2', dislikes='3', part_count=31, end_count=4, music='Нет', genres=['юмор'])
# 14267
# Имя Anastasia Volyanskaya
# Story(id='14267', name='Исчезновение сырка', author='Anastasia Volyanskaya', date_last_version=datetime.datetime(2023, 5, 27, 0, 0), short_description='Загадочная история, о совсем не загадочном объекте', last_month_readed=11, all_readed=414, likes='4', dislikes='3', part_count=134, end_count=63, music='Нет', genres=['детектив'])
# 14280
# Имя Дмитрий Дударь
# Story(id='14280', name='Ян Ливингстон "Храм Ужаса"', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 5, 27, 0, 0), short_description='Интерактивная версия книги-игры "Temple of Terror".  Сможешь ли ты выжить в Пустыне Черепов и найти все Драконьи Артефакты?', last_month_readed=10, all_readed=498, likes='12', dislikes='0', part_count=300, end_count=25, music='Нет', genres=['приключения', 'фэнтези'])
# 14261
# Имя Дартус Вейдерус
# Story(id='14261', name='Жизнь, но ты помидор', author='Дартус Вейдерус', date_last_version=datetime.datetime(2023, 5, 21, 0, 0), short_description='Жил-жил и стал помидором', last_month_readed=11, all_readed=357, likes='11', dislikes='1', part_count=13, end_count=3, music='Нет', genres=['юмор'])
# 14238
# Имя Маг07
# Story(id='14238', name='Приключения одного кота', author='Маг07', date_last_version=datetime.datetime(2023, 6, 29, 0, 0), short_description='Интересное, весёлое и незабываемое приключение кота.', last_month_readed=12, all_readed=195, likes='6', dislikes='4', part_count=10, end_count=2, music='Да', genres=['юмор'])
# 13221
# Имя DDD
# Story(id='13221', name='Остров II', author='DDD', date_last_version=datetime.datetime(2023, 9, 9, 0, 0), short_description='Приключение путешественника, оказавшегося в непростой ситуации. Выбери и объедини 3 предмета, чтобы пройти дальше.', last_month_readed=0, all_readed=115, likes='10', dislikes='0', part_count=29, end_count=2, music='Нет', genres=['приключения'])
# 14092
# Имя DashaSaf
# Story(id='14092', name='Я ищу тебя', author='DashaSaf', date_last_version=datetime.datetime(2023, 5, 2, 0, 0), short_description='Валери с детства мечтала стать детективом. У нее появился шанс попробовать свои способности...', last_month_readed=14, all_readed=265, likes='2', dislikes='2', part_count=49, end_count=4, music='Нет', genres=['детектив'])
# 14182
# Имя Taras Vladimirovich Lichm
# Story(id='14182', name='Катастрофа', author='Taras Vladimirovich Lichm', date_last_version=datetime.datetime(2023, 4, 28, 0, 0), short_description='При катастрофе космического корабля выживают немногие. Но они еще не знают, что их борьба за жизнь только начинается.', last_month_readed=1, all_readed=189, likes='3', dislikes='4', part_count=31, end_count=9, music='Нет', genres=['фантастика'])
# 14167
# Имя test test
# Story(id='14167', name='Мошенник в большом городе', author='test test', date_last_version=datetime.datetime(2023, 4, 27, 0, 0), short_description='Мелкий воришка из небольшого села в Сибири переезжает в столицу округа и ищет способы как обогатится нечестным трудом.', last_month_readed=4, all_readed=236, likes='1', dislikes='4', part_count=10, end_count=2, music='Нет', genres=['юмор'])
# 13426
# Имя elChеm
# Story(id='13426', name='Не спи!', author='elChеm', date_last_version=datetime.datetime(2024, 5, 17, 0, 0), short_description='Где вы окажетесь, когда откроете глаза?', last_month_readed=44, all_readed=1180, likes='12', dislikes='2', part_count=133, end_count=5, music='Нет', genres=['квест', 'поиск', 'ужасы'])
# 12765
# 'Имя'
# None
# 13963
# Имя Дмитрий Дударь
# Story(id='13963', name='Ян Ливингстон "Возвращение к Огненной горе"', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 4, 19, 0, 0), short_description='Интерактивная версия книги-игры "Return to Firetop Mountain" Яна Ливингстона. Злой волшебник Загор вернулся! Огненная гора ждет!', last_month_readed=14, all_readed=240, likes='6', dislikes='0', part_count=340, end_count=16, music='Нет', genres=['фэнтези'])
# 13420
# 'Имя'
# None
# 13934
# Имя Дмитрий Дударь
# Story(id='13934', name='Ян Ливингстон "Склеп Колдуна"', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 4, 13, 0, 0), short_description='Интерактивная версия книги-игры "Crypt of the Sorcerer"  Мечи и магия, монстры и ловушки!', last_month_readed=30, all_readed=675, likes='6', dislikes='0', part_count=332, end_count=16, music='Нет', genres=['фэнтези'])
# 13844
# Имя Дмитрий Дударь
# Story(id='13844', name='Книга-игра "Космический Коммандос"', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 4, 6, 0, 0), short_description='Интерактивная версия книги-игры "Space Assassin" Эндрю Чапмена . Космос, роботы, бластеры!', last_month_readed=5, all_readed=338, likes='6', dislikes='0', part_count=250, end_count=19, music='Нет', genres=['фантастика'])
# 13436
# Имя Дмитрий Дударь
# Story(id='13436', name='Состязание чемпионов', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 3, 15, 0, 0), short_description='Интерактивная версия книги-игры Яна Ливингстона "Trial of  champions". Хватит ли у Вас храбрости, чтобы  снова вернуться в Лабиринт Страха ?', last_month_readed=1, all_readed=394, likes='7', dislikes='0', part_count=374, end_count=16, music='Нет', genres=['фэнтези'])
# 13363
# 'Имя'
# None
# 13398
# Имя Дмитрий Дударь
# Story(id='13398', name='Заложники пиратского адмирала', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 3, 7, 0, 0), short_description='Интерактивная версия книги-игры Ольги Голотвиной "Заложники пиратского адмирала"', last_month_readed=7, all_readed=422, likes='7', dislikes='1', part_count=622, end_count=29, music='Нет', genres=['фантастика'])
# 13374
# 'Имя'
# None
# 13387
# Имя Дмитрий Дударь
# Story(id='13387', name='Арена Славы', author='Дмитрий Дударь', date_last_version=datetime.datetime(2023, 2, 25, 0, 0), short_description='Сразись на Арене с монстрами', last_month_readed=11, all_readed=296, likes='11', dislikes='4', part_count=22, end_count=6, music='Нет', genres=['ролевая игра'])
# 13358
# Имя Gard
# Story(id='13358', name='Печать изгоя: Поцелуй Удачи', author='Gard', date_last_version=datetime.datetime(2023, 3, 12, 0, 0), short_description='Приключения в Таламонте продолжаются', last_month_readed=6, all_readed=917, likes='26', dislikes='3', part_count=346, end_count=33, music='Нет', genres=['приключения'])
# 13356
# Имя elChеm
# Story(id='13356', name='Любовь и запретные небеса', author='elChеm', date_last_version=datetime.datetime(2023, 2, 12, 0, 0), short_description='Вике едва исполнилось четырнадцать, когда её отношения с молодым человеком подверглись первой серьёзной проверке. К чему это может привести?', last_month_readed=9, all_readed=703, likes='14', dislikes='1', part_count=39, end_count=9, music='Нет', genres=['романтика'])
# 10457
# 'Имя'
# None
# 13347
# Имя quest_example
# Story(id='13347', name='Заколдованный вокзал', author='quest_example', date_last_version=datetime.datetime(2023, 2, 8, 0, 0), short_description='Сможешь уехать отсюда?', last_month_readed=6, all_readed=1438, likes='16', dislikes='0', part_count=34, end_count=4, music='Нет', genres=['головоломка'])
# 8761
# 'Имя'
# None
# 10857
# 'Имя'
# None
# 12974
# Имя Антон Иванов
# Story(id='12974', name='Вторая Мировая: Германия', author='Антон Иванов', date_last_version=datetime.datetime(2022, 12, 3, 0, 0), short_description='Альтернативные варианты Второй Мировой от лица Германии.', last_month_readed=141, all_readed=4908, likes='25', dislikes='2', part_count=112, end_count=12, music='Нет', genres=['история'])
# 8550
# 'Имя'
# None
# 13133
# Имя Марина Мелехова
# Story(id='13133', name='Паноптикон', author='Марина Мелехова', date_last_version=datetime.datetime(2022, 11, 10, 0, 0), short_description='откройте новые границы своего сознания', last_month_readed=1, all_readed=641, likes='8', dislikes='2', part_count=90, end_count=13, music='Да', genres=['ужасы'])
# 13104
# Имя MiroGhost
# Story(id='13104', name='Циклон - Эгида (Дидары)', author='MiroGhost', date_last_version=datetime.datetime(2022, 10, 27, 0, 0), short_description='Примите участие в войне Дидар(люди) против Хоудвай(гуманоиды)', last_month_readed=1, all_readed=212, likes='4', dislikes='3', part_count=120, end_count=7, music='Нет', genres=['стратегия'])
# 13100
# Имя Zaratystra
# Story(id='13100', name='Зачарованное королевство', author='Zaratystra', date_last_version=datetime.datetime(2022, 10, 24, 0, 0), short_description='Соблазны Страны Эльфов завлекли в ловушку немало смертных. Ты можешь превратиться в отвратительного монстра или навеки заблудиться...', last_month_readed=7, all_readed=1632, likes='25', dislikes='1', part_count=51, end_count=22, music='Нет', genres=['приключения'])
# 13084
# Имя Zaratystra
# Story(id='13084', name='Супердевушка', author='Zaratystra', date_last_version=datetime.datetime(2022, 10, 21, 0, 0), short_description='Высоко над городом Супердевушка разгоняется до сверхсветовой скорости, с лёгкостью преодолевая временной барьер.', last_month_readed=2, all_readed=560, likes='10', dislikes='2', part_count=25, end_count=11, music='Нет', genres=['приключения'])
# 13085
# Имя Zaratystra
# Story(id='13085', name='Трон Зевса', author='Zaratystra', date_last_version=datetime.datetime(2022, 10, 21, 0, 0), short_description='В этой древней земле боги и герои непредсказуемы. Суждено ли тебе будет вернуться с триумфом … или навсегда пропасть в древней легенде.', last_month_readed=1, all_readed=482, likes='9', dislikes='1', part_count=65, end_count=30, music='Нет', genres=['фантастика'])
# 13076
# Имя Zaratystra
# Story(id='13076', name='Сны в ведьмином доме', author='Zaratystra', date_last_version=datetime.datetime(2024, 3, 8, 0, 0), short_description='Да, и даже не сомневайся: «Ph’nglui mglw’nafh Cthulhu R’lyeh wgah’nagl fhtagn».', last_month_readed=17, all_readed=1516, likes='24', dislikes='0', part_count=91, end_count=8, music='Нет', genres=['ужасы'])
# 13072
# Имя Zaratystra
# Story(id='13072', name='Дракон', author='Zaratystra', date_last_version=datetime.datetime(2022, 10, 20, 0, 0), short_description='Ты – последний драконий воин. \tТёмные, злые силы собираются в Железных Копях. Армия Гралла Жестокого выступаёт в поход!', last_month_readed=8, all_readed=363, likes='6', dislikes='1', part_count=58, end_count=1, music='Нет', genres=['приключения'])
# 12902
# Имя Zaratystra
# Story(id='12902', name='Единорог', author='Zaratystra', date_last_version=datetime.datetime(2022, 10, 20, 0, 0), short_description='Ты – волшебный единорог. \tИмператрица Инь Ян похитила Кармин, красного единорога. Инь Ян хочет уничтожить разноцветную Страну Радуги.', last_month_readed=4, all_readed=439, likes='11', dislikes='1', part_count=60, end_count=1, music='Нет', genres=['приключения'])
# 12980
# Имя Dasun
# Story(id='12980', name='Авантюрист', author='Dasun', date_last_version=datetime.datetime(2022, 11, 11, 0, 0), short_description='Пройди путь авантюриста', last_month_readed=43, all_readed=519, likes='8', dislikes='2', part_count=155, end_count=2, music='Нет', genres=['ролевая игра'])
# 12929
# 'Имя'
# None
# 12939
# 'Имя'
# None
# 12588
# 'Имя'
# None
# 12920
# Имя Gard
# Story(id='12920', name='Печать изгоя: Побег из тени', author='Gard', date_last_version=datetime.datetime(2023, 2, 23, 0, 0), short_description='Мир фэнтези', last_month_readed=6, all_readed=1756, likes='57', dislikes='2', part_count=71, end_count=9, music='Нет', genres=['фэнтези'])
# 12877
# 'Имя'
# None
# 12853
# Имя Михаил Кулешов
# Story(id='12853', name='Ноктюрн для Психопомпа', author='Михаил Кулешов', date_last_version=datetime.datetime(2022, 10, 27, 0, 0), short_description='Научная разведка в интересах Космографического общества.', last_month_readed=5, all_readed=593, likes='18', dislikes='2', part_count=96, end_count=18, music='Нет', genres=['фантастика'])
# 12858
# Имя DDD
# Story(id='12858', name='Остров', author='DDD', date_last_version=datetime.datetime(2023, 9, 9, 0, 0), short_description='Приключение путешественника, оказавшегося в непростой ситуации.  Выбери и объедини 3 предмета, чтобы пройти дальше.', last_month_readed=0, all_readed=424, likes='17', dislikes='1', part_count=14, end_count=2, music='Нет', genres=['приключения'])
# 12671
# 'Имя'
# None
# 12797
# Имя NotPRISHELETS333
# Story(id='12797', name='Тайны Квестбука (для неофитов).  Мастерство метателя кубов.', author='NotPRISHELETS333', date_last_version=datetime.datetime(2022, 7, 15, 0, 0), short_description='Гайд по выживанию в "сложных механиках".', last_month_readed=0, all_readed=108, likes='13', dislikes='0', part_count=28, end_count=1, music='Нет', genres=[])
# 12782
# Имя psychorockboy
# Story(id='12782', name='Охотник на Зло - 1 часть - Техасская резня бензопилой (16+)', author='psychorockboy', date_last_version=datetime.datetime(2023, 6, 11, 0, 0), short_description='Ты - банкир из Техаса. После череды жестоких убийств в твоём городке ты решил задуматься о собственной безопасности.', last_month_readed=2, all_readed=487, likes='8', dislikes='1', part_count=33, end_count=6, music='Нет', genres=['ужасы'])
# 12770
# Имя Михаил Кулешов
# Story(id='12770', name='Ноктюрн для Чёрной Лилии', author='Михаил Кулешов', date_last_version=datetime.datetime(2022, 7, 20, 0, 0), short_description='Тамара Тенебра, анэксадо и (время от времени) преступница, берётся за простую работёнку.', last_month_readed=12, all_readed=5780, likes='32', dislikes='1', part_count=31, end_count=8, music='Нет', genres=['фантастика'])
# 12644
# 'Имя'
# None
# 11891
# Имя Михаил Кулешов
# Story(id='11891', name='Грехи Луны-Беглянки', author='Михаил Кулешов', date_last_version=datetime.datetime(2022, 7, 8, 0, 0), short_description='Исследовательская миссия для Института Святой Пергунды', last_month_readed=10, all_readed=668, likes='20', dislikes='1', part_count=159, end_count=13, music='Нет', genres=['фантастика'])
# 12125
# Имя Элина Сидельникова
# Story(id='12125', name='Знакомство паучков.', author='Элина Сидельникова', date_last_version=datetime.datetime(2022, 6, 21, 0, 0), short_description='Из-за временного разлома человек-паук разных вселенных встретился с другими его подобными.', last_month_readed=1, all_readed=213, likes='6', dislikes='3', part_count=29, end_count=1, music='Нет', genres=['приключения'])
# 12624
# Имя Мэд Ригби
# Story(id='12624', name='Ужасы Карнивэра', author='Мэд Ригби', date_last_version=datetime.datetime(2022, 6, 4, 0, 0), short_description='Кооперативная игра для 1-2 игроков', last_month_readed=3, all_readed=5511, likes='15', dislikes='7', part_count=143, end_count=8, music='Да', genres=['ужасы'])
# 12582
# Имя Данил Федоткин
# Story(id='12582', name='Сломанные часы', author='Данил Федоткин', date_last_version=datetime.datetime(2022, 5, 27, 0, 0), short_description='Квест-игра про путешествие во времени из настоящего во времена СССР', last_month_readed=2, all_readed=281, likes='4', dislikes='2', part_count=47, end_count=6, music='Нет', genres=[])
# 12494
# Имя Юлия Ш.
# Story(id='12494', name='Приключения Олеси', author='Юлия Ш.', date_last_version=datetime.datetime(2022, 5, 18, 0, 0), short_description='Приключения студентки Олеси', last_month_readed=1, all_readed=5746, likes='22', dislikes='6', part_count=65, end_count=3, music='Нет', genres=['приключения'])
# 4956
# Имя KsoLeft
# Story(id='4956', name='Невыдуманный мир', author='KsoLeft', date_last_version=datetime.datetime(2022, 5, 17, 0, 0), short_description='Они считают, что жить в мире, который придуман кем-то другим глупо, намного лучше - творить самому!', last_month_readed=3, all_readed=5774, likes='21', dislikes='2', part_count=46, end_count=6, music='Нет', genres=['фантастика'])
# 12547
# Имя Володя Петров
# Story(id='12547', name='Торговый Центр', author='Володя Петров', date_last_version=datetime.datetime(2022, 5, 14, 0, 0), short_description='Приключения В Магазине', last_month_readed=2, all_readed=224, likes='3', dislikes='6', part_count=22, end_count=2, music='Нет', genres=['повседневность'])
# 12546
# Имя Петроник
# Story(id='12546', name='Эндориум', author='Петроник', date_last_version=datetime.datetime(2022, 5, 12, 0, 0), short_description='Эндориум - когда-то интерактивная аудиоистория, с музыкально-шумовым оформлением. Увы, остался только текст :(', last_month_readed=1, all_readed=5263, likes='12', dislikes='1', part_count=34, end_count=6, music='Нет', genres=['фантастика'])
# 12294
# Имя Анастасия Наумова
# Story(id='12294', name='История одного учёного', author='Анастасия Наумова', date_last_version=datetime.datetime(2022, 4, 17, 0, 0), short_description='А сможешь ли ты за один день стать великим учёным?', last_month_readed=1, all_readed=317, likes='5', dislikes='0', part_count=35, end_count=4, music='Нет', genres=[])
# 12145
# Имя merckeeper
# Story(id='12145', name='Портрет', author='merckeeper', date_last_version=datetime.datetime(2022, 4, 16, 0, 0), short_description='Попробуй не остаться в мирах Короля и Шута', last_month_readed=12, all_readed=5941, likes='26', dislikes='3', part_count=43, end_count=13, music='Нет', genres=['ролевая игра'])
# 12137
# Имя Полина Кузнецова
# Story(id='12137', name='Пропажа пасхального кролика', author='Полина Кузнецова', date_last_version=datetime.datetime(2022, 4, 12, 0, 0), short_description='Удивительная история-детектив в праздничный день.', last_month_readed=0, all_readed=120, likes='5', dislikes='0', part_count=19, end_count=5, music='Нет', genres=['повседневность'])
# 10733
# 'Имя'
# None
# 12015
# Имя imposter _
# ...
# 4936
# Имя Write_right
# Story(id='4936', name='Звериный патриотизм: дневник Йозефа Гёббельса', author='Write_right', date_last_version=datetime.datetime(2018, 11, 9, 0, 0), short_description='Обнаруженный дневник поможет изменить вам ход второй мировой войны.', last_month_readed=6, all_readed=848, likes='32', dislikes='4', part_count=57, end_count=3, music='Нет', genres=['история', 'фантастика'])
# 4904
# Имя Dimon Brodovskiy
# Story(id='4904', name='Стервятник', author='Dimon Brodovskiy', date_last_version=datetime.datetime(2018, 10, 27, 0, 0), short_description='Стервятники бывают разные.', last_month_readed=0, all_readed=234, likes='7', dislikes='9', part_count=98, end_count=26, music='Нет', genres=['фэнтези'])
# 4800
# 'Имя'
# None
# 4935
# 'Имя'
# None
# 4926
# Имя KsoLeft
# Story(id='4926', name='Придворный шут Короля', author='KsoLeft', date_last_version=datetime.datetime(2022, 5, 17, 0, 0), short_description='Король умер, и теперь жестокого наследника должен воспитать шут.', last_month_readed=4, all_readed=4355, likes='108', dislikes='13', part_count=50, end_count=10, music='Нет', genres=[])
# 4833
# Имя Златолюб
# Story(id='4833', name='Затонувшие сокровища', author='Златолюб', date_last_version=datetime.datetime(2018, 10, 10, 0, 0), short_description='Поиск пиратских сокровищ во времена парусников и пиратов', last_month_readed=10, all_readed=1305, likes='29', dislikes='2', part_count=18, end_count=8, music='Нет', genres=['приключения'])
# 4771
# Имя ЮркийСлон
# Story(id='4771', name='Стакан', author='ЮркийСлон', date_last_version=datetime.datetime(2018, 10, 24, 0, 0), short_description='Сможет ли небольшая команда торгового супершипа вырваться из лап корпорации зла?', last_month_readed=6, all_readed=2414, likes='73', dislikes='8', part_count=41, end_count=6, music='Нет', genres=['приключения', 'фантастика'])
# 4806
# Имя Malalit
# Story(id='4806', name='Шкатулка Истины', author='Malalit', date_last_version=datetime.datetime(2018, 10, 8, 0, 0), short_description='Сюжетный сторигейм на конкурс', last_month_readed=0, all_readed=944, likes='28', dislikes='8', part_count=41, end_count=5, music='Нет', genres=['приключения', 'поиск', 'фэнтези'])
# 4811
# Имя Dimon Brodovskiy
# Story(id='4811', name='Украсть курицу', author='Dimon Brodovskiy', date_last_version=datetime.datetime(2018, 12, 15, 0, 0), short_description='Вы очень голодный кот.', last_month_readed=0, all_readed=2377, likes='43', dislikes='17', part_count=27, end_count=12, music='Нет', genres=['симулятор'])
# 4754
# Имя Х_Юрий
# Story(id='4754', name='Академия ордена Лунных Львов', author='Х_Юрий', date_last_version=datetime.datetime(2021, 7, 26, 0, 0), short_description='Экзамен на рыцаря академии Лунных Львов. Сторигейм на конкурс', last_month_readed=0, all_readed=726, likes='33', dislikes='8', part_count=27, end_count=2, music='Нет', genres=['фэнтези'])
# 4799
# Имя Maxim  Brivka
# Story(id='4799', name='Его Величество Рандом', author='Maxim  Brivka', date_last_version=datetime.datetime(2019, 4, 18, 0, 0), short_description='Несколько рандомных испытаний в позабытом мире безумного гения.', last_month_readed=0, all_readed=750, likes='21', dislikes='11', part_count=27, end_count=7, music='Нет', genres=['квест', 'поиск'])
# 4742
# Имя Leem
# Story(id='4742', name='Кладоискатели', author='Leem', date_last_version=datetime.datetime(2018, 10, 5, 0, 0), short_description='Вы со своим псом набрели на странный тоннель. Сторигейм на конкурс.', last_month_readed=0, all_readed=667, likes='24', dislikes='11', part_count=90, end_count=22, music='Нет', genres=['квест'])
# 4783
# Имя Maxim  Brivka
# Story(id='4783', name='Дикая дуэль', author='Maxim  Brivka', date_last_version=datetime.datetime(2019, 12, 17, 0, 0), short_description='Попытка воплотить одно из популярных событий Дикого Запада в формате краткого сторигейма.', last_month_readed=7, all_readed=1418, likes='54', dislikes='6', part_count=35, end_count=3, music='Нет', genres=['боевик'])
# 4781
# Имя Malalit
# Story(id='4781', name='Разрушители. Пролог', author='Malalit', date_last_version=datetime.datetime(2018, 10, 2, 0, 0), short_description='Небольшая завязка интерактивного романа', last_month_readed=3, all_readed=751, likes='27', dislikes='7', part_count=32, end_count=4, music='Нет', genres=['приключения'])
# 4776
# Имя Maxim  Brivka
# Story(id='4776', name='Архивариус', author='Maxim  Brivka', date_last_version=datetime.datetime(2019, 4, 18, 0, 0), short_description='В данном проекте вам предоставиться возможность принять участие в жизни одного необычного архивариуса.', last_month_readed=2, all_readed=671, likes='27', dislikes='8', part_count=23, end_count=4, music='Нет', genres=['приключения', 'мистика'])
# 4769
# Имя Maxim  Brivka
# Story(id='4769', name='Вольный демон Тиазар', author='Maxim  Brivka', date_last_version=datetime.datetime(2018, 10, 2, 0, 0), short_description='История рождения и начала пути вольного демона Тиазара', last_month_readed=1, all_readed=652, likes='11', dislikes='12', part_count=12, end_count=3, music='Нет', genres=['мистика'])
# 4764
# 'Имя'
# None
# 4734
# Имя Leem
# Story(id='4734', name='Красношапкова', author='Leem', date_last_version=datetime.datetime(2018, 9, 24, 0, 0), short_description='Зоя нашла свою бабушку мертвой. Теперь ей предстоит выяснить, что произошло.', last_month_readed=0, all_readed=1532, likes='29', dislikes='13', part_count=49, end_count=16, music='Нет', genres=['сказка', 'детектив'])
# 4733
# Имя Дядя Марат
# Story(id='4733', name='Геймеры против Шпионов', author='Дядя Марат', date_last_version=datetime.datetime(2018, 9, 23, 0, 0), short_description='Геймеры против Шпионов', last_month_readed=1, all_readed=544, likes='14', dislikes='11', part_count=31, end_count=1, music='Нет', genres=['повседневность'])
# 4186
# 'Имя'
# None
# 4685
# Имя ВольнымСтилемПоБорщу
# Story(id='4685', name='Danganronpa: Лекарство от Отчаяния - пролог', author='ВольнымСтилемПоБорщу', date_last_version=datetime.datetime(2018, 9, 12, 0, 0), short_description='Демо-версия пролога фанатской новеллы по серии игр Danganronpa.', last_month_readed=0, all_readed=179, likes='2', dislikes='8', part_count=30, end_count=0, music='Нет', genres=['поиск'])
# 4683
# 'Имя'
# None
# 4678
# Имя Folium
# Story(id='4678', name='9 сентября', author='Folium', date_last_version=datetime.datetime(2018, 9, 4, 0, 0), short_description='9 сентября', last_month_readed=1, all_readed=222, likes='6', dislikes='17', part_count=10, end_count=1, music='Нет', genres=[])
# 4576
# 'Имя'
# None
# 4672
# Имя Jumangee
# Story(id='4672', name='Лука Брази: последнее дело', author='Jumangee', date_last_version=datetime.datetime(2020, 1, 10, 0, 0), short_description='За тобой должок, Лука. Последний должок, помнишь? Твоя цель - Джонни Ирландец…', last_month_readed=6, all_readed=1229, likes='38', dislikes='4', part_count=80, end_count=23, music='Нет', genres=['квест'])
# 4628
# Имя Виктория Большакова
# Story(id='4628', name='Добро пожаловать в Дивный новый мир', author='Виктория Большакова', date_last_version=datetime.datetime(2018, 8, 25, 0, 0), short_description='Рассматриваются возможные сценарии будущего', last_month_readed=3, all_readed=943, likes='18', dislikes='13', part_count=28, end_count=8, music='Нет', genres=['фантастика'])
# 4630
# Имя ALICE
# Story(id='4630', name='Дорогу единорогам!', author='ALICE', date_last_version=datetime.datetime(2018, 8, 25, 0, 0), short_description='Весёлые приключения в волшебном лесу', last_month_readed=1, all_readed=402, likes='10', dislikes='12', part_count=23, end_count=4, music='Нет', genres=['сказка'])
# 4604
# 'Имя'
# None
# 4595
# Имя Pereza
# Story(id='4595', name='(Демо)Ремонт домов', author='Pereza', date_last_version=datetime.datetime(2018, 8, 15, 0, 0), short_description='Симулятор ремонта домов.', last_month_readed=1, all_readed=137, likes='6', dislikes='8', part_count=22, end_count=1, music='Нет', genres=[])
# 4593
# 'Имя'
# None
# 4581
# Имя Pereza
# Story(id='4581', name='2 задания', author='Pereza', date_last_version=datetime.datetime(2018, 8, 11, 0, 0), short_description='Космос. У вас есть одно из двух заданий на выполнение.', last_month_readed=1, all_readed=406, likes='20', dislikes='8', part_count=23, end_count=8, music='Нет', genres=['фантастика'])
# 4578
# Имя Pereza
# Story(id='4578', name='Принеси', author='Pereza', date_last_version=datetime.datetime(2018, 8, 8, 0, 0), short_description='Расширяю познания в использовании редактора.', last_month_readed=0, all_readed=131, likes='7', dislikes='15', part_count=11, end_count=1, music='Нет', genres=['фантастика'])
# 4568
# Имя Pereza
# Story(id='4568', name='Кто убийца? 2(18+)', author='Pereza', date_last_version=datetime.datetime(2018, 8, 6, 0, 0), short_description='Сиквел первой части.', last_month_readed=0, all_readed=221, likes='5', dislikes='10', part_count=21, end_count=3, music='Да', genres=['квест'])
# 4546
# Имя Pereza
# Story(id='4546', name='Охота на медведя.', author='Pereza', date_last_version=datetime.datetime(2018, 8, 7, 0, 0), short_description='(К прочтению не рекомендуется)Игра сделана для конкурса. Версус ковбоя и мутанта-медведя.', last_month_readed=0, all_readed=475, likes='15', dislikes='16', part_count=20, end_count=4, music='Да', genres=['фантастика', 'выживание'])
# 4558
# Имя Irremann
# Story(id='4558', name='Не читайте желтых газет', author='Irremann', date_last_version=datetime.datetime(2018, 8, 5, 0, 0), short_description='Однажды роботы нашли газету..', last_month_readed=4, all_readed=265, likes='22', dislikes='10', part_count=8, end_count=1, music='Нет', genres=['фантастика'])
# 4552
# Имя Anopryan
# Story(id='4552', name='Мини-апокалипсис', author='Anopryan', date_last_version=datetime.datetime(2022, 11, 14, 0, 0), short_description='Мини-стори из 2-х параграфов', last_month_readed=5, all_readed=946, likes='34', dislikes='15', part_count=3, end_count=1, music='Нет', genres=['выживание'])
# 4540
# Имя Pereza
# Story(id='4540', name='Кто убийца?(18+)', author='Pereza', date_last_version=datetime.datetime(2018, 8, 2, 0, 0), short_description='История о ассистенте детектива(осторожно МАТ).', last_month_readed=5, all_readed=469, likes='8', dislikes='12', part_count=18, end_count=3, music='Нет', genres=['выживание', 'квест'])
# 4425
# Имя Anopryan
# Story(id='4425', name='Поваренная книга митрилоюзера', author='Anopryan', date_last_version=datetime.datetime(2020, 10, 23, 0, 0), short_description='Небольшой туториал по созданию игровых механик всех видов и сложностей', last_month_readed=0, all_readed=262, likes='24', dislikes='3', part_count=61, end_count=2, music='Нет', genres=[])
# 4322
# 'Имя'
# None
# 4497
# Имя Nori
# Story(id='4497', name='Адальома. Радужный архипелаг (Главы 1-2)', author='Nori', date_last_version=datetime.datetime(2018, 8, 9, 0, 0), short_description='Путешествие в удивительный мир Адальомы в роли ученика школы магии.', last_month_readed=3, all_readed=2998, likes='85', dislikes='6', part_count=163, end_count=2, music='Нет', genres=['фэнтези', 'романтика'])
# 4455
# Имя Ичиго Куросаки
# Story(id='4455', name='Дом', author='Ичиго Куросаки', date_last_version=datetime.datetime(2018, 7, 23, 0, 0), short_description='Один из тех писателей, кто любит творить ужасы', last_month_readed=1, all_readed=431, likes='10', dislikes='16', part_count=20, end_count=1, music='Нет', genres=['квест'])
# 4411
# Имя Zaratystra
# Story(id='4411', name='Симулятор Киллера', author='Zaratystra', date_last_version=datetime.datetime(2022, 4, 29, 0, 0), short_description='Вам предстоит стать наёмным убийцей в непростом деле', last_month_readed=14, all_readed=12277, likes='193', dislikes='17', part_count=106, end_count=22, music='Да', genres=['симулятор'])
# 4387
# 'Имя'
# None
# 4344
# 'Имя'
# None
# 4311
# Имя Lana Taylor
# Story(id='4311', name='Профессия: Смерть', author='Lana Taylor', date_last_version=datetime.datetime(2018, 6, 22, 0, 0), short_description='Все профессии нужны, все профессии важны...', last_month_readed=7, all_readed=2481, likes='64', dislikes='8', part_count=46, end_count=9, music='Нет', genres=['юмор', 'приключения'])
# 4299
# Имя DDD
# Story(id='4299', name='Квестаун', author='DDD', date_last_version=datetime.datetime(2018, 6, 13, 0, 0), short_description='Приключения в Квестауне', last_month_readed=0, all_readed=868, likes='33', dislikes='7', part_count=48, end_count=1, music='Нет', genres=['приключения'])
# 4313
# Имя TroyHolman
# Story(id='4313', name='100 секунд', author='TroyHolman', date_last_version=datetime.datetime(2020, 5, 9, 0, 0), short_description='Успеть за сто секунд', last_month_readed=2, all_readed=867, likes='30', dislikes='9', part_count=69, end_count=1, music='Нет', genres=['поиск'])
# 4304
# 'Имя'
# None
# 4286
# 'Имя'
# None
# 4284
# Имя Anopryan
# Story(id='4284', name='Обычный день тирана', author='Anopryan', date_last_version=datetime.datetime(2022, 11, 15, 0, 0), short_description='Само название, в принципе,  даёт исчерпывающие количество информации об этом сторигейме)', last_month_readed=5, all_readed=1022, likes='31', dislikes='11', part_count=10, end_count=2, music='Нет', genres=['сказка'])
# 4275
# Имя Таня Карпенко
# Story(id='4275', name='Клетка Единорога', author='Таня Карпенко', date_last_version=datetime.datetime(2018, 5, 31, 0, 0), short_description='Вот что бывает, когда маленькая девочка плохо слушается старших. И когда хорошо слушается - тоже.', last_month_readed=3, all_readed=927, likes='28', dislikes='11', part_count=16, end_count=5, music='Нет', genres=['сказка', 'ужасы'])
# 4258
# Имя Jumangee
# Story(id='4258', name='Гробница полководца', author='Jumangee', date_last_version=datetime.datetime(2020, 1, 10, 0, 0), short_description='Поход Фаргала за своим утерянным мечом, подарком богини Таймат', last_month_readed=4, all_readed=1172, likes='22', dislikes='3', part_count=362, end_count=61, music='Да', genres=['поиск', 'фэнтези', 'легенды'])
# 4203
# Имя Leem
# Story(id='4203', name='Замена (16+)', author='Leem', date_last_version=datetime.datetime(2018, 5, 21, 0, 0), short_description='Их было трое. До начала войны...', last_month_readed=0, all_readed=1904, likes='45', dislikes='10', part_count=58, end_count=15, music='Нет', genres=['выживание'])
# 4253
# 'Имя'
# None
# 4247
# 'Имя'
# None
# 4243
# 'Имя'
# None
# 4227
# Имя Pyrir
# Story(id='4227', name='Симулятор гладиатора', author='Pyrir', date_last_version=datetime.datetime(2018, 4, 29, 0, 0), short_description='Выйди на арену и останься в живых!!!', last_month_readed=6, all_readed=1383, likes='27', dislikes='7', part_count=48, end_count=2, music='Нет', genres=['симулятор'])
# 4182
# Имя Скальд
# Story(id='4182', name='Идеальная книга-игра', author='Скальд', date_last_version=datetime.datetime(2019, 1, 30, 0, 0), short_description='История создания шедевра)', last_month_readed=11, all_readed=2568, likes='81', dislikes='5', part_count=200, end_count=36, music='Да', genres=['юмор', 'повседневность', 'симулятор'])
# 4226
# 'Имя'
# None
# 4223
# 'Имя'
# None
# 4199
# Имя Leem
# Story(id='4199', name='Ученик экзорциста (16+)', author='Leem', date_last_version=datetime.datetime(2018, 4, 15, 0, 0), short_description='Выучитесь на экзорциста и выберите свою сторону', last_month_readed=3, all_readed=2303, likes='48', dislikes='7', part_count=105, end_count=16, music='Нет', genres=['мистика'])
# 4179
# 'Имя'
# None
# 4155
# 'Имя'
# None
# 4143
# 'Имя'
# None
# 4122
# 'Имя'
# None
# 3423
# Имя Jumangee
# list index out of range
# None
# 3421
# Имя Jumangee
# list index out of range
# None
# 2500
# 'Имя'
# None
# 3437
# 'Имя'
# None
# 3436
# Имя Jumangee
# list index out of range
# None
# 3435
# Имя Jumangee
# list index out of range
# None
# 3434
# Имя Jumangee
# list index out of range
# None
# 3433
# Имя Jumangee
# list index out of range
# None
# 3432
# Имя Jumangee
# list index out of range
# None
# 3431
# Имя Jumangee
# list index out of range
# None
# 3428
# Имя Jumangee
# list index out of range
# None
# 3427
# Имя Jumangee
# list index out of range
# None
# 3426
# Имя Jumangee
# list index out of range
# None
# 3425
# Имя Jumangee
# list index out of range
# None
# 3424
# 'Имя'
# None
# 3422
# Имя Jumangee
# list index out of range
# None
# 3420
# Имя Jumangee
# list index out of range
# None
# 2431
# 'Имя'
# None
# 2414
# 'Имя'
# None
# 2404
# 'Имя'
# None
# 2392
# 'Имя'
# None
# 1100
# 'Имя'
# None

# %%
len(stories)
# Out:
# 641

# %%
#cохранение
db_name =  os.getenv('DB_NAME')
db_user = os.getenv('DB_USER')
db_password = os.getenv('DB_PASSWORD')
db_host = 'localhost'
db_port = 5552



with psycopg.connect(
        dbname=db_name,
        user=db_user,
        password=db_password,
        port = db_port,
        autocommit=True
    )as connection:
    with connection.cursor() as cursor:
        for story in stories:
            if story:
                insert_story_and_genres(story,cursor)
# Out:
# An error occurred: invalid input syntax for type integer: "сторигейм месяца"
# CONTEXT:  unnamed portal parameter $8 = '...'

# %%
#проверка наличия данных
with psycopg.connect(
        dbname=db_name,
        user=db_user,
        password=db_password,
        port = db_port
    )as connection:
    with connection.cursor() as cursor:
        cursor.execute("SELECT count(*) FROM stories;")
        #cursor.execute("SELECT count(*) FROM story_genres;")
        
        # Получение всех строк результата
        rows = cursor.fetchall()
        
        # Обработка результата
        for row in rows:
            print(row)
# Out:
# (492,)

# %% [markdown]
# видно что, 149 - не смогли загрузиться.
